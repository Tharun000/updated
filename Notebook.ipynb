# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ['vendor', 'model', 'myct', 'mmin', 'mmax', 'cach', 'chmin', 'chmax','prp', 'erp']

df = pd.read_csv('machine.csv', names = columns, header = None)

# %%
X = df[['myct', 'mmin', 'mmax', 'cach', 'chmin', 'chmax']]
y = df['prp']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
from sklearn.linear_model import LinearRegression

lrv = LinearRegression()
lrv.fit(X_train, y_train)
pred = lrv.predict(X_train)

print('\nLinear Regression - Train accuracy: ', r2_score(y_train, pred))

pred = lrv.predict(X_test)
print('\nLinear Regression - Test accuracy: ', r2_score(y_test, pred))
# Out:
# Linear Regression - Train accuracy:  0.8622983931587525
#
# Linear Regression - Test accuracy:  0.874238221980608

# %%
import pickle

pickle.dump(lrv, open("model.pkl", "wb"))
